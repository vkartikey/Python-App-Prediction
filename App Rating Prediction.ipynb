# %%
import pandas as pd
import numpy as np

# %%
path = r"C:\Users\Asus\Desktop\Simplilearn Projects\googleplaystore.csv"
google_df = pd.read_csv(path)

# %%
google_df.head(25)
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
google_df.info()
google_df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB
# (10841, 13)

# %% [markdown]
# # 2 Checking for null values

# %%
google_df.isnull().any()
# Out:
# App               False
# Category          False
# Rating             True
# Reviews           False
# Size              False
# Installs          False
# Type               True
# Price             False
# Content Rating     True
# Genres            False
# Last Updated      False
# Current Ver        True
# Android Ver        True
# dtype: bool

# %% [markdown]
# Number of null values in each column

# %%
google_df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# # 3 Dropping null values

# %%
google_df.dropna(inplace = True) #Dropping Null Values

# %%
google_df.isnull().any() #verifying for null values
# Out:
# App               False
# Category          False
# Rating            False
# Reviews           False
# Size              False
# Installs          False
# Type              False
# Price             False
# Content Rating    False
# Genres            False
# Last Updated      False
# Current Ver       False
# Android Ver       False
# dtype: bool

# %% [markdown]
# # 4 Formatting the variables

# %%
google_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
google_df['Size'] = [float(i.split('M')[0]) if 'M' in i else float(0) for i in google_df['Size']]

# %%
google_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159  19.0      10,000+  Free     0       Everyone
# 1     967  14.0     500,000+  Free     0       Everyone
# 2   87510   8.7   5,000,000+  Free     0       Everyone
# 3  215644  25.0  50,000,000+  Free     0           Teen
# 4     967   2.8     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
google_df['Size'] = 1000 * google_df['Size']

# %%
google_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews     Size     Installs  Type Price Content Rating  \
# 0     159  19000.0      10,000+  Free     0       Everyone
# 1     967  14000.0     500,000+  Free     0       Everyone
# 2   87510   8700.0   5,000,000+  Free     0       Everyone
# 3  215644  25000.0  50,000,000+  Free     0           Teen
# 4     967   2800.0     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# # 4.2 Converting Reviews from string to float

# %%
google_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9360 non-null   object
#  1   Category        9360 non-null   object
#  2   Rating          9360 non-null   float64
#  3   Reviews         9360 non-null   object
#  4   Size            9360 non-null   float64
#  5   Installs        9360 non-null   object
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   object
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   object
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   object
# dtypes: float64(2), object(11)
# memory usage: 1023.8+ KB

# %%
google_df['Reviews'] = google_df['Reviews'].astype(float)

# %%
google_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9360 non-null   object
#  1   Category        9360 non-null   object
#  2   Rating          9360 non-null   float64
#  3   Reviews         9360 non-null   float64
#  4   Size            9360 non-null   float64
#  5   Installs        9360 non-null   object
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   object
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   object
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 1023.8+ KB

# %% [markdown]
# # 4.3 Removing '+', ',' and converting it to integer

# %%
google_df["Installs"] = [ float(i.replace('+','').replace(',', '')) if '+' in i or ',' in i else float(0) for i in google_df["Installs"] ]

# %%
google_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews     Size    Installs  Type Price Content Rating  \
# 0     159.0  19000.0     10000.0  Free     0       Everyone
# 1     967.0  14000.0    500000.0  Free     0       Everyone
# 2   87510.0   8700.0   5000000.0  Free     0       Everyone
# 3  215644.0  25000.0  50000000.0  Free     0           Teen
# 4     967.0   2800.0    100000.0  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
google_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9360 non-null   object
#  1   Category        9360 non-null   object
#  2   Rating          9360 non-null   float64
#  3   Reviews         9360 non-null   float64
#  4   Size            9360 non-null   float64
#  5   Installs        9360 non-null   float64
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   object
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   object
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   object
# dtypes: float64(4), object(9)
# memory usage: 1023.8+ KB

# %%
google_df['Installs'] = google_df['Installs'].astype(int)

# %%
google_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9360 non-null   object
#  1   Category        9360 non-null   object
#  2   Rating          9360 non-null   float64
#  3   Reviews         9360 non-null   float64
#  4   Size            9360 non-null   float64
#  5   Installs        9360 non-null   int32
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   object
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   object
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   object
# dtypes: float64(3), int32(1), object(9)
# memory usage: 987.2+ KB

# %% [markdown]
# # 4.4 Removing Dollar Sign

# %%
google_df['Price'] = [ float(i.split('$')[1]) if '$' in i else float(0) for i in google_df['Price']]

# %%
google_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews     Size  Installs  Type  Price Content Rating  \
# 0     159.0  19000.0     10000  Free    0.0       Everyone
# 1     967.0  14000.0    500000  Free    0.0       Everyone
# 2   87510.0   8700.0   5000000  Free    0.0       Everyone
# 3  215644.0  25000.0  50000000  Free    0.0           Teen
# 4     967.0   2800.0    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
google_df['Price'] = google_df['Price'].astype(int)

# %%
google_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9360 non-null   object
#  1   Category        9360 non-null   object
#  2   Rating          9360 non-null   float64
#  3   Reviews         9360 non-null   float64
#  4   Size            9360 non-null   float64
#  5   Installs        9360 non-null   int32
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   int32
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   object
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   object
# dtypes: float64(3), int32(2), object(8)
# memory usage: 950.6+ KB

# %% [markdown]
# # Sanity Check

# %% [markdown]
# **1. Dropping Rating exceeding 1 to 5**

# %%
google_df = google_df.drop(google_df[(google_df['Reviews'] < 1) & (google_df['Reviews'] > 5)].index)

# %%
google_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews     Size  Installs  Type  Price Content Rating  \
# 0     159.0  19000.0     10000  Free      0       Everyone
# 1     967.0  14000.0    500000  Free      0       Everyone
# 2   87510.0   8700.0   5000000  Free      0       Everyone
# 3  215644.0  25000.0  50000000  Free      0           Teen
# 4     967.0   2800.0    100000  Free      0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
google_df.shape
# Out:
# (9360, 13)

# %% [markdown]
# **2. Dropping Rows where Reviews > installs**

# %%
google_df.drop(google_df[google_df['Installs'] < google_df['Reviews']].index, inplace = True)

# %%
google_df.shape
# Out:
# (9353, 13)

# %% [markdown]
# **3. Renaming free apps as '0' in Price Column**

# %%
google_df.shape
# Out:
# (9353, 13)

# %%
google_df.drop(google_df[(google_df['Type'] == 'Free') & (google_df['Price'] > 0)].index, inplace = True)

# %% [markdown]
# # 5 Univariate  Analysis

# %% [markdown]
# **Boxplot for price**

# %%
sns.set(rc={'figure.figsize':(15, 6)})

# %%
sns.boxplot(x = 'Price', data = google_df)
plt.show()

# %% [markdown]
# There are some apps whose price is higher than the usual price of the apps

# %% [markdown]
# **Boxplot for Reviews**

# %%
sns.boxplot(x = 'Reviews', data = google_df)
plt.show()

# %% [markdown]
# There are some apps who have higher number of reviews than the usual apps which are considered to be outliers

# %% [markdown]
# **Histogram for Rating**

# %%
plt.hist(google_df['Rating'])
plt.show()

# %% [markdown]
# This is a negatively skewed histogram i.e., majority of the apps have higher ratings

# %% [markdown]
# **Histogram For Size**

# %%
plt.hist(google_df['Size'])
plt.show()

# %% [markdown]
# This is a positively skewed histogram i.e., majority of the apps have lower app size

# %% [markdown]
# # 6. Outlier Treatment

# %% [markdown]
# **6.1 Price**

# %%
#Dropping the apps whose price is higher than $200 as they are outliers
price_outliers = google_df.loc[google_df['Price'] > 200].shape[0]
print('Number of apps having price more than $200 =', price_outliers)
# Out:
# Number of apps having price more than $200 = 15

# %% [markdown]
# yes, $200 for an app is a high price, hence we'll be dropping it

# %%
google_df.shape
# Out:
# (9353, 13)

# %%
google_df.drop(google_df[google_df['Price'] > 200].index, inplace = True)

# %%
google_df.shape
# Out:
# (9338, 13)

# %% [markdown]
# **6.2 Reviews**

# %%
revs = google_df.loc[google_df['Reviews'] > 2000000].shape[0]
print('Number of apps having more than 2 Million Reviews = ', revs)
# Out:
# Number of apps having more than 2 Million Reviews =  453

# %%
#we'll be dropping these highly reviewed apps to make the data more appropriate
google_df.drop(google_df[google_df['Reviews'] > 2000000].index, inplace = True)

# %%
google_df.shape
# Out:
# (8885, 13)

# %% [markdown]
# **6.3 Installs**

# %%
#Calculating quantiles accordingly

google_df.quantile([0.1, 0.25, 0.50, 0.70, 0.90, 0.95, 0.99])
# Out:
#       Rating     Reviews     Size     Installs  Price
# 0.10     3.5       18.00      0.0       1000.0    0.0
# 0.25     4.0      159.00   2600.0      10000.0    0.0
# 0.50     4.3     4290.00   9500.0     500000.0    0.0
# 0.70     4.5    35930.40  23000.0    1000000.0    0.0
# 0.90     4.7   296771.00  50000.0   10000000.0    0.0
# 0.95     4.8   637298.00  68000.0   10000000.0    1.0
# 0.99     5.0  1462800.88  95000.0  100000000.0    7.0

# %%
#we'll drop the values more than the threshold i.e., 95th percentile
google_df.drop(google_df[google_df['Installs'] > 10000000].index, inplace = True)

# %%
google_df.shape
# Out:
# (8496, 13)

# %% [markdown]
# # 7. Bivariate Analysis

# %% [markdown]
# **7.1 Scatter Plot Rating vs Price**

# %%
sns.scatterplot(x = 'Rating', y = 'Price', data = google_df)
plt.show()

# %% [markdown]
# **Joint Plot**

# %%
sns.jointplot(x= 'Rating', y = 'Price', data = google_df)
plt.show()

# %% [markdown]
# In the "Ratings v/s Price" graphs above, they have a positive linear relationship, which states that paid apps have the highest number of ratings

# %% [markdown]
# **7.2 Scatter Plot for Rating v/s Size**

# %%
sns.scatterplot(x = 'Rating', y = 'Size', data = google_df)
plt.show()

# %% [markdown]
# **Joint Plot**

# %%
sns.jointplot(x = 'Rating', y = 'Size', data = google_df)
plt.show()

# %% [markdown]
# In the "Rating v/s Size" graphs above, they have positive linear relationship which means that app who's size are large have higher ratings in comparison to the ones who have low size

# %% [markdown]
# **7.3 Scatter Plot for Rating v/s Reviews**

# %%
sns.scatterplot(x = 'Rating', y = 'Reviews', data = google_df)
plt.show()

# %% [markdown]
# **Joint Plot**

# %%
sns.jointplot(x = 'Rating', y = 'Reviews', data = google_df)
plt.show()

# %% [markdown]
# In the Rating v/s Reviews Graphs as well there is positive linear relationship that means higher number of reviews higher is the rating

# %% [markdown]
# **7.4 Boxplot for Rating v/s Content Rating**

# %%
sns.boxplot(x = 'Rating', y = 'Content Rating', data = google_df)
plt.show()

# %% [markdown]
# Apps for Everyone have the most amount of outliers, there by making them the worst rated apps. Mature 17+, Everyone 10+ and Teen too have some amount of outliers there by falling in the same category. Adult only 18+ apps have no outliers and hence are the most liked apps
# **Most Liked: Adults only 18+**

# %% [markdown]
# **7.5 Boxplot for Rating v/s Category**

# %%
sns.set(rc = {'figure.figsize': (15,15)})
sns.boxplot(x = 'Rating', y = 'Category', data = google_df)
plt.show()

# %% [markdown]
# From the following Categories **'Events'** genre have the best ratings followed by **'Weather'** genre.

# %% [markdown]
# # 8. Data Preprocessing

# %%
inp1 = google_df.copy() #creating a copy of google_df

# %%
inp1.head(10)
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
#
#     Reviews     Size  Installs  Type  Price Content Rating  \
# ...

# %% [markdown]
# **8.1 Applying log transformation to 'Reviews' and 'Installs' Columns**

# %%
inp1.skew() #To check skewness of the data
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_18140\378656718.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   inp1.skew() #To check skewness of the data
# Rating      -1.749753
# Reviews      4.576494
# Size         1.655917
# Installs     1.543697
# Price       18.074542
# dtype: float64

# %%
inp1.describe()
# Out:
#             Rating       Reviews           Size      Installs        Price
# count  8496.000000  8.496000e+03    8496.000000  8.496000e+03  8496.000000
# mean      4.173411  6.566228e+04   18639.701036  2.134612e+06     0.299788
# std       0.533032  1.680637e+05   22158.033336  3.525914e+06     2.142247
# min       1.000000  1.000000e+00       0.000000  5.000000e+00     0.000000
# 25%       4.000000  1.340000e+02    2900.000000  1.000000e+04     0.000000
# 50%       4.300000  3.325500e+03    9800.000000  1.000000e+05     0.000000
# 75%       4.500000  4.205000e+04   26000.000000  1.000000e+06     0.000000
# max       5.000000  1.852384e+06  100000.000000  1.000000e+07    79.000000

# %%
reviews_skew = np.log1p(inp1['Reviews']) #log transformation on Reviews column
inp1['Reviews'] = reviews_skew

# %%
reviews_skew.skew()
# Out:
# -0.20039949659264134

# %%
installs_skew = np.log1p(inp1['Installs']) #log transgormation on Installs column
inp1['Installs'] = installs_skew

# %%
installs_skew.skew()
# Out:
# -0.5097286542754812

# %%
inp1.head(10)
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
#
#       Reviews     Size   Installs  Type  Price Content Rating  \
# ...

# %% [markdown]
# **8.2 Dropping Non-Usefull columns**

# %%
inp1.drop(['App', 'Last Updated', 'Current Ver', 'Android Ver', 'Type'], axis = 1, inplace = True) #for dropping specified columns

# %%
inp1.head(10)
# Out:
#           Category  Rating    Reviews     Size   Installs  Price  \
# 0   ART_AND_DESIGN     4.1   5.075174  19000.0   9.210440      0
# 1   ART_AND_DESIGN     3.9   6.875232  14000.0  13.122365      0
# 2   ART_AND_DESIGN     4.7  11.379520   8700.0  15.424949      0
# 4   ART_AND_DESIGN     4.3   6.875232   2800.0  11.512935      0
# 5   ART_AND_DESIGN     4.4   5.123964   5600.0  10.819798      0
# 6   ART_AND_DESIGN     3.8   5.187386  19000.0  10.819798      0
# 7   ART_AND_DESIGN     4.1  10.513688  29000.0  13.815512      0
# 8   ART_AND_DESIGN     4.4   9.531844  33000.0  13.815512      0
# 9   ART_AND_DESIGN     4.7   4.804021   3100.0   9.210440      0
# 10  ART_AND_DESIGN     4.4   9.538276  28000.0  13.815512      0
#
#    Content Rating                     Genres
# 0        Everyone               Art & Design
# 1        Everyone  Art & Design;Pretend Play
# 2        Everyone               Art & Design
# 4        Everyone    Art & Design;Creativity
# ...

# %%
inp1.shape
# Out:
# (8496, 8)

# %% [markdown]
# **8.3 Dummy Encoding to convert Categorical variables to Numeric ones**

# %%
inp2 = inp1 #creating a copy of data

# %%
inp2.head(10)
# Out:
#           Category  Rating    Reviews     Size   Installs  Price  \
# 0   ART_AND_DESIGN     4.1   5.075174  19000.0   9.210440      0
# 1   ART_AND_DESIGN     3.9   6.875232  14000.0  13.122365      0
# 2   ART_AND_DESIGN     4.7  11.379520   8700.0  15.424949      0
# 4   ART_AND_DESIGN     4.3   6.875232   2800.0  11.512935      0
# 5   ART_AND_DESIGN     4.4   5.123964   5600.0  10.819798      0
# 6   ART_AND_DESIGN     3.8   5.187386  19000.0  10.819798      0
# 7   ART_AND_DESIGN     4.1  10.513688  29000.0  13.815512      0
# 8   ART_AND_DESIGN     4.4   9.531844  33000.0  13.815512      0
# 9   ART_AND_DESIGN     4.7   4.804021   3100.0   9.210440      0
# 10  ART_AND_DESIGN     4.4   9.538276  28000.0  13.815512      0
#
#    Content Rating                     Genres
# 0        Everyone               Art & Design
# 1        Everyone  Art & Design;Pretend Play
# 2        Everyone               Art & Design
# 4        Everyone    Art & Design;Creativity
# ...

# %% [markdown]
# **Applying Dummy encoding to Category Column**

# %% [markdown]
# **Category column**

# %%
inp2['Category'].unique() #for knowing the unique values in the category column
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
inp2.Category = pd.Categorical(inp2.Category)

x = inp2[['Category']]
del inp2['Category']

dummies = pd.get_dummies(x, prefix = 'Category')
inp2 = pd.concat([inp2, dummies], axis = 1)
inp2.head(10)
# Out:
#     Rating    Reviews     Size   Installs  Price Content Rating  \
# 0      4.1   5.075174  19000.0   9.210440      0       Everyone
# 1      3.9   6.875232  14000.0  13.122365      0       Everyone
# 2      4.7  11.379520   8700.0  15.424949      0       Everyone
# 4      4.3   6.875232   2800.0  11.512935      0       Everyone
# 5      4.4   5.123964   5600.0  10.819798      0       Everyone
# 6      3.8   5.187386  19000.0  10.819798      0       Everyone
# 7      4.1  10.513688  29000.0  13.815512      0       Everyone
# 8      4.4   9.531844  33000.0  13.815512      0       Everyone
# 9      4.7   4.804021   3100.0   9.210440      0       Everyone
# 10     4.4   9.538276  28000.0  13.815512      0       Everyone
#
#                        Genres  Category_ART_AND_DESIGN  \
# 0                Art & Design                        1
# 1   Art & Design;Pretend Play                        1
# 2                Art & Design                        1
# ...

# %% [markdown]
# **Genres Column**

# %%
inp2['Genres'].unique()
# Out:
# array(['Art & Design', 'Art & Design;Pretend Play',
#        'Art & Design;Creativity', 'Auto & Vehicles', 'Beauty',
#        'Books & Reference', 'Business', 'Comics', 'Comics;Creativity',
#        'Communication', 'Dating', 'Education', 'Education;Creativity',
#        'Education;Education', 'Education;Music & Video',
#        'Education;Action & Adventure', 'Education;Pretend Play',
#        'Education;Brain Games', 'Entertainment',
#        'Entertainment;Brain Games', 'Entertainment;Creativity',
#        'Entertainment;Music & Video', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Lifestyle;Pretend Play', 'Card', 'Casual', 'Puzzle',
#        'Action', 'Arcade', 'Word', 'Racing', 'Casual;Creativity',
#        'Sports', 'Board', 'Simulation', 'Role Playing', 'Adventure',
#        'Strategy', 'Simulation;Education', 'Action;Action & Adventure',
# ...

# %% [markdown]
# We are going to streamline the genres since there are too many genres and will assigning them to a single category called 'Other'

# %%
lists = [] #Empty list

for i in inp2.Genres.value_counts().index: #getting total no. of genres and if less than 20 then assigning them to a new category Other
    if inp2.Genres.value_counts()[i] < 20:        lists.append(i)
        
inp2.Genres = ['Other' if i in lists else i for i in inp2.Genres] #changing the genres to other

# %%
inp2['Genres'].unique()
# Out:
# array(['Art & Design', 'Other', 'Auto & Vehicles', 'Beauty',
#        'Books & Reference', 'Business', 'Comics', 'Communication',
#        'Dating', 'Education', 'Education;Education',
#        'Education;Pretend Play', 'Entertainment',
#        'Entertainment;Music & Video', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Card', 'Casual', 'Puzzle', 'Action', 'Arcade',
#        'Word', 'Racing', 'Sports', 'Board', 'Simulation', 'Role Playing',
#        'Adventure', 'Strategy', 'Trivia', 'Educational;Education',
#        'Casual;Pretend Play', 'Medical', 'Social', 'Shopping',
#        'Photography', 'Travel & Local', 'Tools', 'Personalization',
#        'Productivity', 'Parenting', 'Weather', 'Video Players & Editors',
#        'News & Magazines', 'Maps & Navigation', 'Educational', 'Casino'],
#       dtype=object)

# %%
inp2.Genres = pd.Categorical(inp2['Genres']) #genres column into x variable
x = inp2[['Genres']]
del inp2['Genres'] #deleting the Genres column

#encoding and storing the dummies values in dataset
dummies = pd.get_dummies(x, prefix = 'Genres')
inp2 = pd.concat([inp2, dummies], axis = 1)

# %%
inp2.head(10)
# Out:
#     Rating    Reviews     Size   Installs  Price Content Rating  \
# 0      4.1   5.075174  19000.0   9.210440      0       Everyone
# 1      3.9   6.875232  14000.0  13.122365      0       Everyone
# 2      4.7  11.379520   8700.0  15.424949      0       Everyone
# 4      4.3   6.875232   2800.0  11.512935      0       Everyone
# 5      4.4   5.123964   5600.0  10.819798      0       Everyone
# 6      3.8   5.187386  19000.0  10.819798      0       Everyone
# 7      4.1  10.513688  29000.0  13.815512      0       Everyone
# 8      4.4   9.531844  33000.0  13.815512      0       Everyone
# 9      4.7   4.804021   3100.0   9.210440      0       Everyone
# 10     4.4   9.538276  28000.0  13.815512      0       Everyone
#
#     Category_ART_AND_DESIGN  Category_AUTO_AND_VEHICLES  Category_BEAUTY  \
# 0                         1                           0                0
# 1                         1                           0                0
# ...

# %% [markdown]
# **Content Rating Column**

# %%
inp2['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
inp2['Content Rating'] = pd.Categorical(inp2['Content Rating'])

x = inp2[['Content Rating']]
del inp2['Content Rating']

dummies = pd.get_dummies(x, prefix = 'Content Rating')
inp2 = pd.concat([inp2, dummies], axis = 1)
inp2.head(10)
# Out:
#     Rating    Reviews     Size   Installs  Price  Category_ART_AND_DESIGN  \
# 0      4.1   5.075174  19000.0   9.210440      0                        1
# 1      3.9   6.875232  14000.0  13.122365      0                        1
# 2      4.7  11.379520   8700.0  15.424949      0                        1
# 4      4.3   6.875232   2800.0  11.512935      0                        1
# 5      4.4   5.123964   5600.0  10.819798      0                        1
# 6      3.8   5.187386  19000.0  10.819798      0                        1
# 7      4.1  10.513688  29000.0  13.815512      0                        1
# 8      4.4   9.531844  33000.0  13.815512      0                        1
# 9      4.7   4.804021   3100.0   9.210440      0                        1
# 10     4.4   9.538276  28000.0  13.815512      0                        1
#
#     Category_AUTO_AND_VEHICLES  Category_BEAUTY  Category_BOOKS_AND_REFERENCE  \
# ...

# %% [markdown]
# # 9. Train and Test Splitting the Data
# # 10. Separating the df into "X_train, X_test, y_train, y_test"

# %%
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LinearRegression as LR
from sklearn.metrics import mean_squared_error as mse
from sklearn import metrics

# %% [markdown]
# Creating X and Y variables; X = Independent Features; Y = Target Feature

# %%
ml1 = inp2
X = ml1.drop('Rating', axis = 1)
y = ml1['Rating']

X_train, X_test, y_train, y_test = tts(X, y, test_size = 0.3, random_state = 5)

# %%
print('Shape of X_train =', X_train.shape)
print('Shape of X_test =', X_test.shape)
print('Shape of y_train =', y_train.shape)
print('Shape of y_test =', y_test.shape)
# Out:
# Shape of X_train = (5947, 95)
# Shape of X_test = (2549, 95)
# Shape of y_train = (5947,)
# Shape of y_test = (2549,)

# %% [markdown]
# # 11. Model Building

# %% [markdown]
# **11.1 Linear Regression Model Used**

# %%
#Using Linear Regression technique
lr = LR()
lr.fit(X_train, y_train) #lr = LinearRegression
# Out:
# LinearRegression()

# %%
print("Intercept of Linear Regression Model = ", lr.intercept_)
# Out:
# Intercept of Linear Regression Model =  4.60580786346828

# %%
print("Column Names for Co-Efficient =", ml1.columns)
print("Co-Efficient of Linear Regression Model = ", lr.coef_)
# Out:
# Column Names for Co-Efficient = Index(['Rating', 'Reviews', 'Size', 'Installs', 'Price',
#        'Category_ART_AND_DESIGN', 'Category_AUTO_AND_VEHICLES',
#        'Category_BEAUTY', 'Category_BOOKS_AND_REFERENCE', 'Category_BUSINESS',
#        'Category_COMICS', 'Category_COMMUNICATION', 'Category_DATING',
#        'Category_EDUCATION', 'Category_ENTERTAINMENT', 'Category_EVENTS',
#        'Category_FAMILY', 'Category_FINANCE', 'Category_FOOD_AND_DRINK',
#        'Category_GAME', 'Category_HEALTH_AND_FITNESS',
#        'Category_HOUSE_AND_HOME', 'Category_LIBRARIES_AND_DEMO',
#        'Category_LIFESTYLE', 'Category_MAPS_AND_NAVIGATION',
#        'Category_MEDICAL', 'Category_NEWS_AND_MAGAZINES', 'Category_PARENTING',
#        'Category_PERSONALIZATION', 'Category_PHOTOGRAPHY',
#        'Category_PRODUCTIVITY', 'Category_SHOPPING', 'Category_SOCIAL',
#        'Category_SPORTS', 'Category_TOOLS', 'Category_TRAVEL_AND_LOCAL',
# ...

# %% [markdown]
# **11.2 R2 on Train Dataset**

# %%
R2score_train = round(lr.score(X_train, y_train), 3)

print("R2 Score for the Training Data Set is", R2score_train)
# Out:
# R2 Score for the Training Data Set is 0.157

# %% [markdown]
# # 12. Predictions on Test Set

# %%
y_test_pred = lr.predict(X_test)

pd.DataFrame({'Actual y_test' : y_test,
             'Predict y_test' : y_test_pred}).head(25)
# Out:
#        Actual y_test  Predict y_test
# 10720            4.4        4.260388
# 8766             4.4        4.270425
# 601              3.9        3.903414
# 5018             3.9        4.068528
# 2365             4.6        3.857821
# 45               4.7        4.580476
# 3841             4.3        4.149186
# 10017            3.8        4.063879
# 4019             3.7        3.894693
# 7019             4.5        4.068653
# 19               4.6        4.621031
# 8519             4.0        4.315640
# 4165             3.4        4.225490
# 8856             4.6        4.420731
# 7927             3.8        3.977881
# 7327             4.4        4.130030
# 8473             3.7        4.316438
# 1166             4.6        4.332419
# 1334             4.6        4.426608
# 9366             4.6        3.927775
# 10564            5.0        4.478557
# 3860             4.3        3.975022
# 5668             4.0        4.153535
# 5758             4.4        3.898609
# ...

# %%
R2score_test = round(lr.score(X_test, y_test), 3)

print("R2 Score for the Test Data Set is", R2score_test)
# Out:
# R2 Score for the Test Data Set is 0.141
